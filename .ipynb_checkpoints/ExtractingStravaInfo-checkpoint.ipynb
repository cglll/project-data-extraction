# %% [markdown]
# # Strava API research
# ### The objective of this area is to review the strava extraction.

# %%
import requests
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

#Making request URL
auth_url = "https://www.strava.com/oauth/token"
activites_url = "https://www.strava.com/api/v3/athlete/activities"

#Payload
payload = {
    'client_id': "56132",
    'client_secret': 'bd6f5f7e7f96f5b058d7128151995c280e327a72',
    'refresh_token': 'dfcced002b6003a4a0f99327b170af9930ec63ba',
    'grant_type': "refresh_token",
    'f': 'json'
}

#Need to refresh token
print("Requesting Token...\n")
#Posting Request
res = requests.post(auth_url, data=payload, verify=False)
#Pulling access token
access_token = res.json()['access_token']
#New token refreshed
print("Access Token = {}\n".format(access_token))


header = {'Authorization': 'Bearer ' + access_token}
param = {'per_page': 200, 'page': 1}
my_dataset = requests.get(activites_url, headers=header, params=param).json()

print(my_dataset[0]["name"])
print(my_dataset[0]["map"]["summary_polyline"])
# Out:
# Requesting Token...
#
# Access Token = c1c2067e50f502e7602476e19907def9f5ea5e32
#
# Vuelta ciclista vespertina
# clr|Bd_|cRbDy@j@?DDN^HFv@QC?INKE_@@e@Jm@PMNLEWKB?A@VMr@UTKH_@P[M]MAWL?BLh@VLRBl@Ul@OT?@LABuA^WRM?YF[B[L}@h@CKBIpAg@TILA?CK?eBp@}@Ai@G

# %%
print(len(my_dataset))
# Out:
# 129

# %%
#Saving my of activities info to json file

import json 
#Function to save data
def savefile(name):
    with open(name, 'w') as json_file:
        json.dump(my_dataset, json_file)

savefile('strava_cgll_data.json')

# %%
#Getting clubs name
clubs_url = "https://www.strava.com/api/v3/athlete/clubs"
#Header
header = {'Authorization': 'Bearer ' + access_token}
#params
params = {
    'page': "1",
    'per_page': '30',

}
my_clubs = requests.get(clubs_url, headers=header, params=param).json()
savefile('strava_cgll_clubs.json')

# %%
import json
import pandas as pd

# read file
with open('strava_cgll_data.json', 'r') as myfile:
    data=myfile.read()

# parse file
obj = json.loads(data)

print(json.dumps(obj[0], indent=2))
print(len(obj))

data_list=[]
for i in range(len(obj)):
    data_list.append(obj[i])

df = pd.DataFrame(data_list)

df

#pd.DataFrame( columns=['athlete_ID', 'athlete_name', 'activity_ID', 'activity_name','moving_time','elapsed_time','distance','start_date',\
#                           'start_date_local','average_speed','max_speed','average_heartrate','max_heartrate','elev_high','elev_low'])
#for elem in obj:
# Out:
# {
#   "resource_state": 2,
#   "athlete": {
#     "id": 27541670,
#     "resource_state": 1
#   },
#   "name": "Vuelta ciclista vespertina",
#   "distance": 15591.3,
#   "moving_time": 3556,
#   "elapsed_time": 3836,
#   "total_elevation_gain": 7.0,
#   "type": "Ride",
#   "workout_type": null,
#   "id": 4332231042,
#   "external_id": "garmin_push_5816067849",
#   "upload_id": 4631030279,
#   "start_date": "2020-11-13T01:15:42Z",
#   "start_date_local": "2020-11-12T19:15:42Z",
#   "timezone": "(GMT-06:00) America/Mexico_City",
#   "utc_offset": -21600.0,
#   "start_latlng": [
#     20.583086,
#     -100.423498
#   ],
#   "end_latlng": [
#     20.583301,
#     -100.422366
#   ],
#   "location_city": null,
#   "location_state": null,
#   "location_country": null,
#   "start_latitude": 20.583086,
#   "start_longitude": -100.423498,
#   "achievement_count": 0,
#   "kudos_count": 1,
#   "comment_count": 0,
#   "athlete_count": 1,
#   "photo_count": 0,
#   "map": {
#     "id": "a4332231042",
#     "summary_polyline": "clr|Bd_|cRbDy@j@?DDN^HFv@QC?INKE_@@e@Jm@PMNLEWKB?A@VMr@UTKH_@P[M]MAWL?BLh@VLRBl@Ul@OT?@LABuA^WRM?YF[B[L}@h@CKBIpAg@TILA?CK?eBp@}@Ai@G",
#     "resource_state": 2
#   },
#   "trainer": false,
#   "commute": false,
#   "manual": false,
#   "private": false,
#   "visibility": "followers_only",
#   "flagged": false,
#   "gear_id": null,
#   "from_accepted_tag": false,
#   "upload_id_str": "4631030279",
#   "average_speed": 4.385,
#   "max_speed": 7.2,
#   "average_temp": 26,
#   "device_watts": false,
#   "has_heartrate": true,
#   "average_heartrate": 130.2,
#   "max_heartrate": 152.0,
#   "heartrate_opt_out": false,
#   "display_hide_heartrate_option": true,
#   "elev_high": 1803.4,
#   "elev_low": 1789.8,
#   "pr_count": 0,
#   "total_photo_count": 0,
#   "has_kudoed": false
# }
# 129
#      resource_state                                athlete  \
# 0                 2  {'id': 27541670, 'resource_state': 1}
# 1                 2  {'id': 27541670, 'resource_state': 1}
# 2                 2  {'id': 27541670, 'resource_state': 1}
# 3                 2  {'id': 27541670, 'resource_state': 1}
# 4                 2  {'id': 27541670, 'resource_state': 1}
# ..              ...                                    ...
# 124               2  {'id': 27541670, 'resource_state': 1}
# 125               2  {'id': 27541670, 'resource_state': 1}
# 126               2  {'id': 27541670, 'resource_state': 1}
# 127               2  {'id': 27541670, 'resource_state': 1}
# 128               2  {'id': 27541670, 'resource_state': 1}
#
#                                 name  distance  moving_time  elapsed_time  \
# 0         Vuelta ciclista vespertina   15591.3         3556          3836
# 1         Vuelta ciclista vespertina   13117.6         3729          5679
# 2         Vuelta ciclista vespertina      15.8           20           241
# 3         Vuelta ciclista vespertina   21528.4         6153         11726
# 4         Vuelta ciclista vespertina       0.0         2368          2368
# ..                               ...       ...          ...           ...
# 124  Vuelta ciclística por la mañana     407.9           83            83
# 125  Vuelta ciclística por la mañana    2406.3          655           663
# 126  Vuelta ciclística por la mañana     427.6           90            90
# 127  Vuelta ciclística por la mañana     407.5           90            90
# 128                  Hamster wheel 2   13766.7         2419          2689
#
#      total_elevation_gain  type  workout_type          id  ... elev_high  \
# 0                     7.0  Ride           NaN  4332231042  ...    1803.4
# 1                    32.0  Ride           NaN  4298641588  ...    1809.4
# 2                     0.0  Ride           NaN  4298640064  ...    1802.6
# 3                   134.0  Ride           NaN  4269402216  ...    1912.4
# 4                     0.0  Ride           NaN  3995429001  ...       NaN
# ..                    ...   ...           ...         ...  ...       ...
# 124                   0.0  Ride          10.0  2850214231  ...    1805.6
# 125                   0.0  Ride          10.0  2845448824  ...    1805.6
# 126                   0.0  Ride          10.0  2845425742  ...    1805.6
# 127                   0.0  Ride          10.0  2845417080  ...    1805.6
# 128                   0.0  Ride          10.0  2842898623  ...    1805.6
#
#      elev_low pr_count total_photo_count has_kudoed  average_cadence  \
# 0      1789.8        0                 0      False              NaN
# 1      1761.4        0                 0      False              NaN
# 2      1798.8        0                 0      False              NaN
# 3      1767.8        0                 0      False              NaN
# 4         NaN        0                 0      False             40.0
# ..        ...      ...               ...        ...              ...
# 124    1804.6        0                 0      False              NaN
# 125    1804.6        0                 0      False              NaN
# 126    1804.6        0                 0      False              NaN
# 127    1804.6        0                 0      False              NaN
# 128    1804.6        0                 0      False              NaN
#
#     average_watts weighted_average_watts kilojoules max_watts
# 0             NaN                    NaN        NaN       NaN
# 1             NaN                    NaN        NaN       NaN
# 2             NaN                    NaN        NaN       NaN
# 3             NaN                    NaN        NaN       NaN
# 4             NaN                    NaN        NaN       NaN
# ..            ...                    ...        ...       ...
# 124           NaN                    NaN        NaN       NaN
# 125           NaN                    NaN        NaN       NaN
# 126           NaN                    NaN        NaN       NaN
# 127           NaN                    NaN        NaN       NaN
# 128           NaN                    NaN        NaN       NaN
#
# [129 rows x 57 columns]

# %%
#Review nulls in columns
df_clean=df.copy()
null_cols = df_clean.isnull().sum()
null_cols[null_cols > 0]
#Drop columns that only have nulls
drop_cols = list(null_cols[null_cols > 126].index)
df_clean = df_clean.drop(drop_cols, axis=1)
df_clean
#null_cols[null_cols>0]
# Out:
#      resource_state                                athlete  \
# 0                 2  {'id': 27541670, 'resource_state': 1}
# 1                 2  {'id': 27541670, 'resource_state': 1}
# 2                 2  {'id': 27541670, 'resource_state': 1}
# 3                 2  {'id': 27541670, 'resource_state': 1}
# 4                 2  {'id': 27541670, 'resource_state': 1}
# ..              ...                                    ...
# 124               2  {'id': 27541670, 'resource_state': 1}
# 125               2  {'id': 27541670, 'resource_state': 1}
# 126               2  {'id': 27541670, 'resource_state': 1}
# 127               2  {'id': 27541670, 'resource_state': 1}
# 128               2  {'id': 27541670, 'resource_state': 1}
#
#                                 name  distance  moving_time  elapsed_time  \
# 0         Vuelta ciclista vespertina   15591.3         3556          3836
# 1         Vuelta ciclista vespertina   13117.6         3729          5679
# 2         Vuelta ciclista vespertina      15.8           20           241
# 3         Vuelta ciclista vespertina   21528.4         6153         11726
# 4         Vuelta ciclista vespertina       0.0         2368          2368
# ..                               ...       ...          ...           ...
# 124  Vuelta ciclística por la mañana     407.9           83            83
# 125  Vuelta ciclística por la mañana    2406.3          655           663
# 126  Vuelta ciclística por la mañana     427.6           90            90
# 127  Vuelta ciclística por la mañana     407.5           90            90
# 128                  Hamster wheel 2   13766.7         2419          2689
#
#      total_elevation_gain  type  workout_type          id  ...  \
# 0                     7.0  Ride           NaN  4332231042  ...
# 1                    32.0  Ride           NaN  4298641588  ...
# 2                     0.0  Ride           NaN  4298640064  ...
# 3                   134.0  Ride           NaN  4269402216  ...
# 4                     0.0  Ride           NaN  3995429001  ...
# ..                    ...   ...           ...         ...  ...
# 124                   0.0  Ride          10.0  2850214231  ...
# 125                   0.0  Ride          10.0  2845448824  ...
# 126                   0.0  Ride          10.0  2845425742  ...
# 127                   0.0  Ride          10.0  2845417080  ...
# 128                   0.0  Ride          10.0  2842898623  ...
#
#     average_heartrate  max_heartrate heartrate_opt_out  \
# 0               130.2          152.0             False
# 1               131.0          153.0             False
# 2               105.0          151.0             False
# 3               128.1          173.0             False
# 4               102.4          126.0             False
# ..                ...            ...               ...
# 124               NaN            NaN             False
# 125               NaN            NaN             False
# 126               NaN            NaN             False
# 127               NaN            NaN             False
# 128               NaN            NaN             False
#
#     display_hide_heartrate_option elev_high  elev_low pr_count  \
# 0                            True    1803.4    1789.8        0
# 1                            True    1809.4    1761.4        0
# 2                            True    1802.6    1798.8        0
# 3                            True    1912.4    1767.8        0
# 4                            True       NaN       NaN        0
# ..                            ...       ...       ...      ...
# 124                         False    1805.6    1804.6        0
# 125                         False    1805.6    1804.6        0
# 126                         False    1805.6    1804.6        0
# 127                         False    1805.6    1804.6        0
# 128                         False    1805.6    1804.6        0
#
#     total_photo_count  has_kudoed  average_cadence
# 0                   0       False              NaN
# 1                   0       False              NaN
# 2                   0       False              NaN
# 3                   0       False              NaN
# 4                   0       False             40.0
# ..                ...         ...              ...
# 124                 0       False              NaN
# 125                 0       False              NaN
# 126                 0       False              NaN
# 127                 0       False              NaN
# 128                 0       False              NaN
#
# [129 rows x 49 columns]

# %%
#Df is null
null_cols = df_clean.isnull().sum()
list_null=list(null_cols[null_cols > 0].keys())
print(list_null)
#Clear nulls
df_clean[list_null] = df_clean[list_null].fillna(-1)
# Out:
# []

# %%
import numpy as np
low_variance = []
 
for col in df_clean._get_numeric_data():
    minimum = min(df_clean[col])
    ninety_perc = np.percentile(df_clean[col], 90)
    if ninety_perc == minimum:
        low_variance.append(col)
print(low_variance)
df_clean = df_clean.drop(low_variance,axis=1)
# Out:
# ['resource_state', 'comment_count', 'photo_count', 'commute', 'manual', 'private', 'flagged', 'from_accepted_tag', 'heartrate_opt_out', 'pr_count', 'total_photo_count', 'has_kudoed']

# %%
#outlayer
stats = df_clean.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats

outliers = pd.DataFrame(columns=df_clean.columns)
 
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = df_clean[(df_clean[col] < lower) | 
                   (df_clean[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
#Need to review each one this an help to find fault data like recording cycling activity while you go into your pcar
with pd.option_context('display.max_rows', 5, 'display.max_columns', None): 
    display(outliers.head(1))
#print(outliers.head(1))
# Out:
#                                  athlete                        name  \
# 3  {'id': 27541670, 'resource_state': 1}  Vuelta ciclista vespertina
#
#    distance moving_time elapsed_time  total_elevation_gain  type  \
# 3   21528.4        6153        11726                 134.0  Ride
#
#    workout_type          id             external_id   upload_id  \
# 3          -1.0  4269402216  garmin_push_5755882078  4567081685
#
#              start_date      start_date_local  \
# 3  2020-11-01T00:41:08Z  2020-10-31T18:41:08Z
#
#                           timezone  utc_offset              start_latlng  \
# 3  (GMT-06:00) America/Mexico_City    -21600.0  [20.583649, -100.422766]
#
#                  end_latlng  start_latitude  start_longitude  \
# 3  [20.583317, -100.422267]       20.583649      -100.422766
#
#   achievement_count kudos_count athlete_count  \
# 3                 1           2             6
#
#                                                  map trainer      visibility  \
# 3  {'id': 'a4269402216', 'summary_polyline': 'uds...   False  followers_only
#
#   upload_id_str  average_speed  max_speed  average_temp device_watts  \
# 3    4567081685          3.499        8.8          25.0        False
#
#   has_heartrate  average_heartrate  max_heartrate  \
# 3          True              128.1          173.0
#
#   display_hide_heartrate_option  elev_high  elev_low  average_cadence  \
# 3                          True     1912.4    1767.8             -1.0
#
#     Outlier
# 3  distance

# %%
df_clean.dtypes
# Out:
# athlete                           object
# name                              object
# distance                         float64
# moving_time                        int64
# elapsed_time                       int64
# total_elevation_gain             float64
# type                              object
# workout_type                     float64
# id                                 int64
# external_id                       object
# upload_id                          int64
# start_date                        object
# start_date_local                  object
# timezone                          object
# utc_offset                       float64
# start_latlng                      object
# end_latlng                        object
# start_latitude                   float64
# start_longitude                  float64
# achievement_count                  int64
# kudos_count                        int64
# athlete_count                      int64
# map                               object
# trainer                             bool
# visibility                        object
# upload_id_str                     object
# average_speed                    float64
# max_speed                        float64
# average_temp                     float64
# device_watts                      object
# has_heartrate                       bool
# average_heartrate                float64
# max_heartrate                    float64
# display_hide_heartrate_option       bool
# elev_high                        float64
# elev_low                         float64
# average_cadence                  float64
# dtype: object

# %% [markdown]
# ### This part is not working. Strava scrapping the webpage

# %%
import http.cookiejar as cookielib
import time
import urllib
#import urllib2
from bs4 import BeautifulSoup


#from credentials import *

TIME_BT_REQUESTS = 0.5

def log_in():
    print ("Logging in...")
    cj = cookielib.CookieJar()
    opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))

    f = opener.open('https://www.strava.com/login')
    soup = BeautifulSoup(f.read())

    time.sleep(TIME_BT_REQUESTS)

    utf8 = soup.findAll('input', {'name': 'utf8'})[0].get('value').encode('utf-8')
    token = soup.findAll('input', {'name': 'authenticity_token'})[0].get('value')
    
    

    values = {
        'utf8': utf8,
        'authenticity_token': token,
        'email': 'cglllcglll@gmail.com',
        'password': 'Holamundo9.',
    }

    data = urllib.parse.urlencode(values)
    print(data)
    url = 'https://www.strava.com/session'
    
    response = opener.open(url, data)
    soup = BeautifulSoup(response.read())
    print(soup)
    time.sleep(TIME_BT_REQUESTS)
    return opener

def get_athlete_info(opener, athlete_id):
    # without these headers, the request doesn't return anything
    opener.addheaders = [
        ('X-Requested-With', 'XMLHttpRequest'),
        ('Accept', 
            ('text/javascript, application/javascript, application/ecmascript,'
            ' application/x-ecmascript')
        ),
    ]

    url = 'http://www.strava.com/athletes/%s/profile_sidebar_comparison' \
            % athlete_id
    try:
        response = opener.open(url)
    except e:
        print ('%s - %s' % (e, athlete_id))
        return {'error': 'fail5'}

    if response.getcode() != 200:
        raise Exception('Athlete info: %s - %s' % \
                (response.getcode(), response.msg))

    soup = BeautifulSoup(response.read())
    time.sleep(TIME_BT_REQUESTS)

    # find the data we're interested in
    run_info = list(soup.childGenerator())[4]

    # first get the 10k record
    try:
        records = list(run_info.childGenerator())[7]
        records = list(records.childGenerator())[3]
    except:
        return {'error': 'fail1'}

    ten_k = None
    for item in records.childGenerator():
        if '10k' in str(item):
            record = list(item.childGenerator())[3]
            record = record.text 

            # time is in the format 1:02:23 or 45:54
            # convert it to seconds
            splitted = record.split(':')
            try:
                seconds = int(splitted[-1]) + int(splitted[-2]) * 60
            except:
                return {'error': 'fail4'}
            if len(splitted) == 3:
                seconds += int(splitted[0]) * 3600
            ten_k = seconds
            break

    if not ten_k:
        return {'error': 'fail2'}

    # then see if the user was active all year (don't want
    # to include people that just started using strava, since they may
    # have training outsite of strava that would mess the results)
    this_year = list(run_info.childGenerator())[9]
    this_year = list(this_year.childGenerator())[3]
    this_year = list(this_year.childGenerator())[1]
    this_year = list(this_year.childGenerator())[3].text

    all_time = list(run_info.childGenerator())[11]
    all_time = list(all_time.childGenerator())[3]
    all_time = list(all_time.childGenerator())[1]
    all_time = list(all_time.childGenerator())[3].text

    if this_year == all_time:
        return {'error': 'fail3'}

    if 'km' not in this_year:
        raise Exception('weird')
    this_year = float(this_year[:-2].replace(',',''))

    return {
        '10k': ten_k,
        'year': this_year
    }

# %%
import time

import requests
import simplejson as json

TIME_BT_REQUESTS = 0.5

def get_athletes():
	# taking athletes from http://www.strava.com/challenges/turn-up-the-heat-run
	# there are 17311 athletes registered for that challenge
	total_pages = int(173 / 50)

	athletes = []
	for page in range(1, total_pages + 2):
		url = ('http://www.strava.com/challenges/192/details?paging_type='
				'overall&per_page=50&overall_page=%s&overall_male_page=1'
				'&overall_female_page=1&_=1384604957879') % page

		r = requests.get(url)
		data = json.loads(r.text)
		athletes.extend(data['athletes'].values())

		print (len(athletes))
		time.sleep(TIME_BT_REQUESTS)

# %%
	athletes = get_athletes()
	opener = log_in()
# Out:
# 50
# 100
# 150
# 200
# Logging in...
# utf8=%E2%9C%93&authenticity_token=pissmKUj9r1N%2F43q2FmhxUrC%2BnP2lFMDNvU9rYXR2Cd1n2MrYNINKA7zRfcbN2pO7%2FYIcCrZw10LnRIsjxAkqw%3D%3D&email=cglllcglll%40gmail.com&password=Holamundo9.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a9bcf299442c> in <module>
#       1 athletes = get_athletes()
# ----> 2 opener = log_in()
#
# <ipython-input-31-fcb26441cbf9> in log_in()
#      36     url = 'https://www.strava.com/session'
#      37
# ---> 38     response = opener.open(url, data)
#      39     soup = BeautifulSoup(response.read())
#      40     print(soup)
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     520         for processor in self.process_request.get(protocol, []):
#     521             meth = getattr(processor, meth_name)
# --> 522             req = meth(req)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_request_(self, request)
#    1279                 msg = "POST data should be bytes, an iterable of bytes, " \
#    1280                       "or a file object. It cannot be of type str."
# -> 1281                 raise TypeError(msg)
#    1282             if not request.has_header('Content-type'):
#    1283                 request.add_unredirected_header(
#
# TypeError: POST data should be bytes, an iterable of bytes, or a file object. It cannot be of type str.

# %%
	athletes = get_athletes()
	opener = log_in()

	athlete_data = {}

	count_valid = 0
	count_invalid = 0
	total = 0

	for athlete in athletes:
		info = get_athlete_info(opener, athlete['id'])
		athlete_data[athlete['id']] = info

#		if 'error' in info:
#			count_invalid += 1
#		else:
#			count_valid += 1

#		total += 1
#		if total % 50 == 0:
#			print ('%s %s %s' % (total, count_valid, count_invalid))

	athlete_data = [
			(key, item['10k'], item['year']) 
			for key, item in athlete_data.iteritems()
			if '10k' in item
	]
# Out:
# 50
# 100
# 150
# 200
# Logging in...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-4498a4935bd2> in <module>
#       1 athletes = get_athletes()
# ----> 2 opener = log_in()
#       3
#       4 athlete_data = {}
#       5
#
# <ipython-input-27-f7938d7b6e98> in log_in()
#      34     data = urllib.parse.urlencode(values)
#      35     url = 'https://www.strava.com/session'
# ---> 36     response = opener.open(url, data)
#      37     soup = BeautifulSoup(response.read())
#      38     print(soup)
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     520         for processor in self.process_request.get(protocol, []):
#     521             meth = getattr(processor, meth_name)
# --> 522             req = meth(req)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_request_(self, request)
#    1279                 msg = "POST data should be bytes, an iterable of bytes, " \
#    1280                       "or a file object. It cannot be of type str."
# -> 1281                 raise TypeError(msg)
#    1282             if not request.has_header('Content-type'):
#    1283                 request.add_unredirected_header(
#
# TypeError: POST data should be bytes, an iterable of bytes, or a file object. It cannot be of type str.

# %%
from bs4 import BeautifulSoup
import requests


VERSION = '0.1.0'


class StravaScraper(object):
    # https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/User-Agent
    USER_AGENT = "stravalib-scraper/%s" % VERSION

    HEADERS = {'User-Agent': USER_AGENT}

    BASE_URL = "https://www.strava.com"

    URL_LOGIN = "%s/login" % BASE_URL
    URL_SESSION = "%s/session" % BASE_URL
    URL_DASHBOARD = "%s/dashboard" % BASE_URL

    is_authed = False

    # The content from the /dashboard request post-login (if you'd like to
    # reference it at some point)
    dashboard_content = None

    def __init__(self, email, password):
        self.email = email
        self.password = password
        self.session = requests.Session()

    def get_page(self, url):
        response = self.session.get(url, headers=StravaScraper.HEADERS)
        response.raise_for_status()
        return response

    def login(self):
        response = self.get_page(StravaScraper.URL_LOGIN)
        soup = BeautifulSoup(response.content, 'html.parser')
        utf8 = soup.find_all('input',
                             {'name': 'utf8'})[0].get('value').encode('utf-8')
        token = soup.find_all('input',
                              {'name': 'authenticity_token'})[0].get('value')
        data = {
            'utf8': utf8,
            'authenticity_token': token,
            'plan': "",
            'email': self.email,
            'password': self.password,
        }
        response = self.session.post(StravaScraper.URL_SESSION,
                                     data=data,
                                     headers=StravaScraper.HEADERS)
        response.raise_for_status()
        # Simulate that redirect here:
        response = self.get_page(StravaScraper.URL_DASHBOARD)
        print(response)
        #assert("<h2>Activity Feed</h2>" in response.content)
        self.is_authed = True
        # Save this in case someone wants it later...
        self.dashboard_content = response.content

def main():
    import sys

    if len(sys.argv) < 3:
        print (sys.stderr, "Usage: ./scraper.py \"cglllcglll@gmail.com\" \"Holamundo9.\" [url=\"https://www.strava.com/login\"]")
        sys.exit(1)
    email, password = sys.argv[1:3]
    scraper = StravaScraper(email, password)
    scraper.login()
    if len(sys.argv) < 4:
        # No custom URL to hit, just print the dashboard HTML
        print (scraper.dashboard_content)
        return
    # You can pass a custom URL to hit, such as:
    # "https://www.strava.com/challenges/rapha-rising-circle-of-death"
    url = sys.argv[3]
    response = scraper.get_page(url)
    print (response.content)


if __name__ == '__main__':
    main()
# Out:
# <Response [200]>
# b'<!-- Application Layout -->\n<!DOCTYPE html>\n<html class=\'logged-out fullscreen responsive swimming-background-1 feed3p0 old-login\' dir=\'ltr\' lang=\'en-US\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\' xmlns=\'http://www.w3.org/TR/html5\'>\n<!--\nlayout application\n-->\n<head>\n<meta charset=\'UTF-8\'>\n<meta content=\'width = device-width, initial-scale = 1, maximum-scale = 1\' name=\'viewport\'>\n<style type=\'text/css\'>\n.spinner, .spinner .status {\n  position: relative;\n}\n.spinner {\n  margin-top: 1em;\n  margin-bottom: 1em;\n}\n.spinner .status {\n  top: 2px;\n  margin-left: 0.5em;\n}\n.spinner .status:empty {\n  display: none;\n}\n.spinner.lg .graphic {\n  border-width: 3px;\n  height: 32px;\n  width: 32px;\n}\n.spinner.tiny {\n  height: 10px;\n  width: 10px;\n}\n.spinner.centered, .spinner.vcentered {\n  box-sizing: border-box;\n  width: 100%;\n}\n.spinner.vcentered {\n  left: 0;\n  margin-top: -12px;\n  position: absolute;\n  right: 0;\n  text-align: center;\n  top: 50%;\n}\n.spinner .graphic, .ajax-loading-image {\n  animation: spin 1.2s infinite linear;\n  box-sizing: border-box;\n  border-color: #eee;\n  border-radius: 50%;\n  border-style: solid;\n  border-top-color: #666;\n  border-top-style: solid;\n  border-width: 2px;\n  content: "";\n  display: inline-block;\n  height: 20px;\n  position: relative;\n  vertical-align: middle;\n  width: 20px;\n}\n@keyframes spin {\n  from {\n    transform: rotate(0deg);\n  }\n  to {\n    transform: rotate(359deg);\n  }\n}\n</style>\n\n<link rel="stylesheet" media="screen" href="https://d3nn82uaxijpm6.cloudfront.net/assets/strava-app-icons-dff4c105de7bc4e5105473cf3756c5a991ebd5e39a5bc3ee0110afa6e0425650.css" />\n<link rel="stylesheet" media="screen" href="https://d3nn82uaxijpm6.cloudfront.net/assets/strava-app-registration-da0c25a10240c86fda0be897720d20ab6e564e5413ece38ed3571850b4545d6b.css" />\n\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-180x180.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'180x180\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-152x152.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'152x152\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-144x144.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'144x144\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-120x120.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'120x120\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-114x114.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'114x114\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-76x76.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'76x76\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-72x72.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'72x72\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-60x60.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'60x60\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/apple-touch-icon-57x57.png?v=dLlWydWlG8\' rel=\'apple-touch-icon\' sizes=\'57x57\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/favicon-32x32.png?v=dLlWydWlG8\' rel=\'icon\' sizes=\'32x32\' type=\'image/png\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/icon-strava-chrome-192.png?v=dLlWydWlG8\' rel=\'icon\' sizes=\'192x192\' type=\'image/png\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/favicon-96x96.png?v=dLlWydWlG8\' rel=\'icon\' sizes=\'96x96\' type=\'image/png\'>\n<link href=\'https://d3nn82uaxijpm6.cloudfront.net/favicon-16x16.png?v=dLlWydWlG8\' rel=\'icon\' sizes=\'16x16\' type=\'image/png\'>\n<link href=\'/manifest.json?v=dLlWydWlG8\' rel=\'manifest\'>\n<meta content=\'#FC5200\' name=\'msapplication-TileColor\'>\n<meta content=\'https://d3nn82uaxijpm6.cloudfront.net/mstile-144x144.png?v=dLlWydWlG8\' name=\'msapplication-TileImage\'>\n<meta content=\'#FC5200 ...

# %% [markdown]
# ## References API
# #### http://developers.strava.com/docs/reference/
# #### https://github.com/fpolignano/
# #### https://github.com/Tafkas/strava-postman-collection.git
# #### https://github.com/hozn/stravalib

# %% [markdown]
# ## References scrapper
# #### https://github.com/terrettaz/strava-tools
# #### https://github.com/loisaidasam/stravalib-scraper
# #### https://github.com/andreiolariu/data-mining-strava/blob/master/get_athlete_info.py
